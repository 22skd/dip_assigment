# %%
import cv2
import numpy as np

# Read an image from file in grayscale
image = cv2.imread('/content/image1.jpeg')

# Define the kernel for morphological operations
kernel = np.ones((5, 5), np.uint8)

# Perform opening and closing operations
opened_image = cv2.morphologyEx(image, cv2.MORPH_OPEN, kernel)
closed_image = cv2.morphologyEx(image, cv2.MORPH_CLOSE, kernel)

# Display the opened and closed images
cv2_imshow( opened_image)
cv2_imshow( closed_image)
cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FD43087A200>
# <PIL.Image.Image image mode=RGB size=300x168 at 0x7FD430879900>
